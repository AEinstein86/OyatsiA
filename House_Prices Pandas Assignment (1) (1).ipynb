# %%
#1.Read the house prices CSV file shared on E-Learning
import pandas as pd
hdf=pd.read_csv("house_prices.csv")
hdf.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#2.Replace all column values which contain ‘?’ and 'n.a' and 'null' with NaN (Hint :use the read_csv argument called na_values)
# 3. Print out the first 20 rows
fdf=pd.read_csv("house_prices.csv",index_col=["Id"],na_values=["?","n.a","null"])
fdf.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
# 11          20       RL         70.0    11200   Pave   NaN      Reg
# 12          60       RL         85.0    11924   Pave   NaN      IR1
# 13          20       RL          NaN    12968   Pave   NaN      IR2
# ...

# %%
#4.Print out the last 20 rows
ldf=pd.read_csv("house_prices.csv",index_col=["Id"],na_values=["?","n.a","null"])
ldf.tail(20)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1452          20       RL         78.0     9262   Pave   NaN      Reg
# ...

# %%
#5.Print out the first and last 20 rows as one datafame.(Hint use pandas concat function)
cdf=pd.concat([fdf,ldf])
cdf.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
# 11          20       RL         70.0    11200   Pave   NaN      Reg
# 12          60       RL         85.0    11924   Pave   NaN      IR1
# 13          20       RL          NaN    12968   Pave   NaN      IR2
# ...

# %%
#6.Print out the columns
hdf.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#6.Print out the shape
hdf.shape
# Out:
# (1460, 81)

# %%
#6.Print out the information about the dataset
hdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#7.State how many rows and columns the dataset has; in addition to this, how many int, float and object variables are present.
#Rows:1460,Columns:81.Int64 Variables:35,float64 Variables:3,Object Variables:43

# %%
#8.Rename column ‘BldgType’ to BuildingType, ‘RoofMatl’ to RoofMaterial, ‘MoSold’
#to MonthSold and ‘YrSold’ to YearSold.

hdf.rename(columns={
    "BldgType":"BuildingType",
    "RoofMatl":"RoofMaterial",
    "MoSold":"MonthSold",
    "YrSold":"YearSold"
},inplace=True)
hdf.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BuildingType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMaterial', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
#9.Get the Summary Statistics of the DataSet and Explain them
hdf.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
#10.Check for missing values.
values_missing=hdf.isna()
values_missing
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
#11.How many missing values do we have on each column?
values_missing.sum().sort_values(ascending=False)[0:50]
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMaterial        0
# RoofStyle           0
# YearBuilt           0
# LotConfig           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BuildingType        0
# Condition2          0
# BsmtFinSF1          0
# MSZoning            0
# LotArea             0
# Street              0
# Condition1          0
# ...

# %%
#12.Try calculating the percentage of missing values on each column(Hint:total_missing_values/total length of dataframe * 100)
(values_missing.sum()/len(hdf)*100)[0:50]
# Out:
# Id               0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage     17.739726
# LotArea          0.000000
# Street           0.000000
# Alley           93.767123
# LotShape         0.000000
# LandContour      0.000000
# Utilities        0.000000
# LotConfig        0.000000
# LandSlope        0.000000
# Neighborhood     0.000000
# Condition1       0.000000
# Condition2       0.000000
# BuildingType     0.000000
# HouseStyle       0.000000
# OverallQual      0.000000
# OverallCond      0.000000
# YearBuilt        0.000000
# YearRemodAdd     0.000000
# RoofStyle        0.000000
# RoofMaterial     0.000000
# Exterior1st      0.000000
# Exterior2nd      0.000000
# MasVnrType       0.547945
# MasVnrArea       0.547945
# ExterQual        0.000000
# ExterCond        0.000000
# Foundation       0.000000
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinSF1       0.000000
# ...

# %%
#13.Drop Column Alley
hdf=pd.read_csv("house_prices.csv")
hdf.drop(columns=["Alley"],inplace=True)
hdf.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
#
# ...

# %%
#14.Drop Column PoolQC


hdf.drop(columns=["PoolQC"],inplace=True)

hdf.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
#
# ...

# %%
# As you can see the columns Alley and PoolQC have been dropped. 
hdf.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
#15.Drop all rows that have missing values in either BsmtFinType2 or BsmtQual
pd.options.display.max_columns=80
hdf.dropna(subset=["BsmtQual","BsmtFinType2"],axis=0,how="all")
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
#16.Fill in the missing values in LotFrontage with the Mean of LotFrontage
# mean of LotFrontage = 70.04995836802665 (hdf["LotFrontage"].mean())
sdf=hdf.fillna(hdf.mean())
sdf.LotFrontage[0:50]
# Out:
# Id
# 1      65.000000
# 2      80.000000
# 3      68.000000
# 4      60.000000
# 5      84.000000
# 6      85.000000
# 7      75.000000
# 8      70.049958
# 9      51.000000
# 10     50.000000
# 11     70.000000
# 12     85.000000
# 13     70.049958
# 14     91.000000
# 15     70.049958
# 16     51.000000
# 17     70.049958
# 18     72.000000
# 19     66.000000
# 20     70.000000
# 21    101.000000
# 22     57.000000
# 23     75.000000
# 24     44.000000
# 25     70.049958
# 26    110.000000
# 27     60.000000
# 28     98.000000
# 29     47.000000
# 30     60.000000
# 31     50.000000
# 32     70.049958
# 33     85.000000
# 34     70.000000
# 35     60.000000
# 36    108.000000
# 37    112.000000
# 38     74.000000
# 39     68.000000
# 40     65.000000
# 41     84.000000
# 42    115.000000
# 43     70.049958
# 44     70.049958
# 45     70.000000
# 46     61.000000
# 47     48.000000
# 48     84.000000
# 49     33.000000
# 50     66.000000
# Name: LotFrontage, dtype: float64

# %%
#17.Create a New column LotAreaMetres which will be The value of LotArea in Square Metres. (1 square foot = 0.092903Square Metres)

hdf["LotAreaMetres"]=hdf["LotArea"]*0.092903
hdf
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
#18.Set the Id column as the new index.
hdf=pd.read_csv("house_prices.csv")
hdf
hdf.set_index("Id",inplace=True)
hdf
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
#18.Set the Id column as the new index.
#Another way to set Id as the new index:
hdf=pd.read_csv("house_prices.csv",index_col="Id")
hdf
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
#19.Using loc.
#a.Return a dataframe with rows at index 6,54 and 70.
hdf.loc[[6,54,70]]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 54          20       RL         68.0    50271   Pave   NaN      IR1
# 70          50       RL         81.0    15593   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 6          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 54         Low    AllPub    Inside       Gtl      Veenker       Norm
# 70         Lvl    AllPub    Corner       Gtl      ClearCr       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 6        Norm     1Fam     1.5Fin            5            5       1993
# 54       Norm     1Fam     1Story            9            5       1981
# 70       Norm     1Fam     1.5Fin            7            4       1953
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# ...

# %%
#19.Using iloc.
#a.Return a dataframe with rows at index 6,54 and 70.
hdf=pd.read_csv("house_prices.csv",index_col=["Id"])
hdf
hdf.iloc[[5,53,69]]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 54          20       RL         68.0    50271   Pave   NaN      IR1
# 70          50       RL         81.0    15593   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 6          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 54         Low    AllPub    Inside       Gtl      Veenker       Norm
# 70         Lvl    AllPub    Corner       Gtl      ClearCr       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 6        Norm     1Fam     1.5Fin            5            5       1993
# 54       Norm     1Fam     1Story            9            5       1981
# 70       Norm     1Fam     1.5Fin            7            4       1953
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# ...

# %%
#19.Using Loc and Iloc
#b.Return a dataframe with rows from index 50 onwards
hdf.loc[50:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 50            20       RL         66.0     7742   Pave   NaN      Reg
# 51            60       RL          NaN    13869   Pave   NaN      IR2
# 52            50       RM         52.0     6240   Pave   NaN      Reg
# 53            90       RM        110.0     8472   Grvl   NaN      IR2
# 54            20       RL         68.0    50271   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
#19.Using iloc
#b.Return a dataframe with rows from index 50 onwards
hdf.iloc[49:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 50            20       RL         66.0     7742   Pave   NaN      Reg
# 51            60       RL          NaN    13869   Pave   NaN      IR2
# 52            50       RM         52.0     6240   Pave   NaN      Reg
# 53            90       RM        110.0     8472   Grvl   NaN      IR2
# 54            20       RL         68.0    50271   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
#19.Using loc.
#c.Return a dataframe with rows at index 50 to index 100 and columns MSSubClass, LotFrontage,LotArea and SalePrice.
hdf.loc[50:100],["MSSubClass","LotFrontage","LotArea","SalePrice"]
# Out:
# (     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
#  Id
#  50           20       RL         66.0     7742   Pave   NaN      Reg
#  51           60       RL          NaN    13869   Pave   NaN      IR2
#  52           50       RM         52.0     6240   Pave   NaN      Reg
#  53           90       RM        110.0     8472   Grvl   NaN      IR2
#  54           20       RL         68.0    50271   Pave   NaN      IR1
#  55           80       RL         60.0     7134   Pave   NaN      Reg
#  56           20       RL        100.0    10175   Pave   NaN      IR1
#  57          160       FV         24.0     2645   Pave  Pave      Reg
#  58           60       RL         89.0    11645   Pave   NaN      IR1
#  59           60       RL         66.0    13682   Pave   NaN      IR2
#  60           20       RL         60.0     7200   Pave   NaN      Reg
#  61           20       RL         63.0    13072   Pave   NaN      Reg
# ...

# %%
##19.c.Return a dataframe with rows at index 50 to index 100 and columns MSSubClass, LotFrontage,LotArea and SalePrice.
hdf.iloc[49:100],[1,3,4,80]
# Out:
# (     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
#  Id
#  50           20       RL         66.0     7742   Pave   NaN      Reg
#  51           60       RL          NaN    13869   Pave   NaN      IR2
#  52           50       RM         52.0     6240   Pave   NaN      Reg
#  53           90       RM        110.0     8472   Grvl   NaN      IR2
#  54           20       RL         68.0    50271   Pave   NaN      IR1
#  55           80       RL         60.0     7134   Pave   NaN      Reg
#  56           20       RL        100.0    10175   Pave   NaN      IR1
#  57          160       FV         24.0     2645   Pave  Pave      Reg
#  58           60       RL         89.0    11645   Pave   NaN      IR1
#  59           60       RL         66.0    13682   Pave   NaN      IR2
#  60           20       RL         60.0     7200   Pave   NaN      Reg
#  61           20       RL         63.0    13072   Pave   NaN      Reg
# ...

# %%
#Using loc
#19.d.Return a dataframe with all rows and columns SalePrice, and SaleCondition
hdf.loc[:,["SalePrice","SaleCondition"]]
# Out:
#       SalePrice SaleCondition
# Id
# 1        208500        Normal
# 2        181500        Normal
# 3        223500        Normal
# 4        140000       Abnorml
# 5        250000        Normal
# ...         ...           ...
# 1456     175000        Normal
# 1457     210000        Normal
# 1458     266500        Normal
# 1459     142125        Normal
# 1460     147500        Normal
#
# [1460 rows x 2 columns]

# %%
#19.Using iloc
#d.Return a dataframe with all rows and columns SalePrice, and SaleCondition
hdf.iloc[:,[78,79]]
# Out:
#      SaleCondition  SalePrice
# Id
# 1           Normal     208500
# 2           Normal     181500
# 3           Normal     223500
# 4          Abnorml     140000
# 5           Normal     250000
# ...            ...        ...
# 1456        Normal     175000
# 1457        Normal     210000
# 1458        Normal     266500
# 1459        Normal     142125
# 1460        Normal     147500
#
# [1460 rows x 2 columns]

# %%
#20.Use corr() function to find the correlation among the columns in the dataframe using ‘Pearson’ method.
#Note:The correlation of a variable with itself is 1. For that reason all the diagonal values are 1.00.
#The output dataframe can be interpreted as for any cell, row variable correlation with the column variable is the value of the cell.
import pandas as pd
pd.options.display.max_columns=80
hdf=pd.read_csv("house_prices.csv",index_col=["Id"],na_values=["?","n.a","null"])
hdf.head(10)
hdf.corr(method="pearson")
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.386347 -0.139781     0.032628    -0.059316
# LotFrontage     -0.386347     1.000000  0.426095     0.251646    -0.059213
# LotArea         -0.139781     0.426095  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.251646  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.059213 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.123349  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.088866  0.013788     0.550684     0.073741
# MasVnrArea       0.022936     0.193458  0.104160     0.411876    -0.128101
# BsmtFinSF1      -0.069836     0.233633  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.049900  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.132644 -0.002618     0.308159    -0.136841
# ...

# %%
#21.Use corr() function to find the correlation among the columns in the dataframe using ‘kendall’ method.
#Note:The correlation of a variable with itself is 1. For that reason all the diagonal values are 1.00.
#The output dataframe can be interpreted as for any cell, row variable correlation with the column variable is the value of the cell.
import pandas as pd
pd.options.display.max_columns=80
hdf=pd.read_csv("house_prices.csv",index_col=["Id"],na_values=["?","n.a","null"])
hdf.head(10)
hdf.corr(method="kendall")
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.236067 -0.200790     0.083506    -0.057833
# LotFrontage     -0.236067     1.000000  0.510666     0.193309    -0.065029
# LotArea         -0.200790     0.510666  1.000000     0.173136    -0.036164
# OverallQual      0.083506     0.193309  0.173136     1.000000    -0.152513
# OverallCond     -0.057833    -0.065029 -0.036164    -0.152513     1.000000
# YearBuilt        0.010922     0.138978  0.074436     0.505804    -0.329379
# YearRemodAdd    -0.003649     0.083595  0.053329     0.437687    -0.031641
# MasVnrArea       0.018061     0.197848  0.132267     0.341051    -0.149822
# BsmtFinSF1      -0.079554     0.112092  0.120827     0.104062    -0.012308
# BsmtFinSF2      -0.071900     0.042690  0.057501    -0.101893     0.092477
# BsmtUnfSF       -0.086258     0.082474  0.052923     0.205094    -0.096586
# ...

# %%
#22.What is the highest sale Price in the dataset?
Highest_Sale_Price=hdf["SalePrice"].max()
Highest_Sale_Price
# Out:
# 755000

# %%
#23.Return a dataframe with information on the most expensive house in the dataset.
hdf.sort_values(["SalePrice"],ascending=False)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 692           60       RL        104.0    21535   Pave   NaN      IR1
# 1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1170          60       RL        118.0    35760   Pave   NaN      IR1
# 899           20       RL        100.0    12919   Pave   NaN      IR1
# 804           60       RL        107.0    13891   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 31            70  C (all)         50.0     8500   Pave  Pave      Reg
# 534           20       RL         50.0     5000   Pave   NaN      Reg
# 969           50       RM         50.0     5925   Pave   NaN      Reg
# 917           20  C (all)         50.0     9000   Pave   NaN      Reg
# 496           30  C (all)         60.0     7879   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
#23.Return a dataframe with information on the most expensive house in the dataset.
filt1=hdf["SalePrice"]==755000
hdf[filt1]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 691  692          60       RL        104.0    21535   Pave      IR1
#
#     LandContour Utilities LotConfig  ... ScreenPorch PoolArea Fence  \
# 691         Lvl    AllPub    Corner  ...           0        0   NaN
#
#     MiscFeature MiscVal MonthSold  YearSold  SaleType  SaleCondition  \
# 691         NaN       0         1      2007        WD         Normal
#
#      SalePrice
# 691     755000
#
# [1 rows x 79 columns]

# %%
#24.Return a dataframe with only houses whose price is higher than 500000?
hdf.loc[hdf["SalePrice"]>500000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 178    179          20       RL         63.0    17423   Pave      IR1
# 440    441          20       RL        105.0    15431   Pave      Reg
# 691    692          60       RL        104.0    21535   Pave      IR1
# 769    770          60       RL         47.0    53504   Pave      IR2
# 803    804          60       RL        107.0    13891   Pave      Reg
# 898    899          20       RL        100.0    12919   Pave      IR1
# 1046  1047          60       RL         85.0    16056   Pave      IR1
# 1169  1170          60       RL        118.0    35760   Pave      IR1
# 1182  1183          60       RL        160.0    15623   Pave      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea  Fence  \
# 178          Lvl    AllPub   CulDSac  ...           0        0    NaN
# 440          Lvl    AllPub    Inside  ...         170        0    NaN
# ...

# %%
#25.What is the Mean Price of a house according to its SaleCondition?
hdf.groupby(["SaleCondition"]).mean().sort_values("SalePrice",ascending=False)
# Out:
#                        Id  MSSubClass  LotFrontage       LotArea  OverallQual  \
# SaleCondition
# Partial        701.936000   49.840000    79.104839  11254.920000     7.560000
# Normal         733.630217   57.378965    69.124870  10543.478297     6.006678
# Alloca         688.750000   70.833333    64.800000  11499.583333     5.416667
# Family         747.900000   57.250000    73.333333   9604.050000     5.800000
# Abnorml        741.336634   57.673267    67.928571   9450.801980     5.574257
# AdjLand        450.250000   70.000000    54.500000   8002.500000     5.000000
#
#                OverallCond    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# SaleCondition
# Partial           5.024000  2005.200000   2006.640000  203.778689  510.560000
# Normal            5.659432  1969.030885   1983.702003   96.550251  439.469115
# Alloca            5.166667  1967.916667   1980.166667   82.727273  550.666667
# Family            5.350000  1962.100000   1976.450000   88.500000  446.600000
# ...

# %%
#26.What is the average price for houses built before 2010?
filt_1=((hdf["YearBuilt"]<2010) & (hdf["SalePrice"]))
hdf[filt_1].mean()
#Average Price=248973.217391
# Out:
# MSSubClass           53.478261
# LotFrontage          75.066667
# LotArea           10606.673913
# OverallQual           6.934783
# OverallCond           5.195652
# YearBuilt          1990.108696
# YearRemodAdd       1999.195652
# MasVnrArea          158.478261
# BsmtFinSF1          359.413043
# BsmtFinSF2           29.130435
# BsmtUnfSF           887.347826
# TotalBsmtSF        1275.891304
# 1stFlrSF           1334.608696
# 2ndFlrSF            418.695652
# LowQualFinSF          0.000000
# GrLivArea          1753.304348
# BsmtFullBath          0.391304
# BsmtHalfBath          0.043478
# FullBath              1.739130
# HalfBath              0.543478
# BedroomAbvGr          2.804348
# KitchenAbvGr          1.086957
# TotRmsAbvGrd          7.630435
# Fireplaces            0.673913
# GarageYrBlt        1995.086957
# GarageCars            2.304348
# GarageArea          614.000000
# WoodDeckSF           98.260870
# OpenPorchSF          58.608696
# EnclosedPorch        15.956522
# ...

# %%
#27.Create two dataframes using the dictionaries below then merge them using inner,outer, right, left join?
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995,
135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower':
[141, 80, 182 , 160]}

Car_Pricedf=pd.DataFrame(Car_Price)
Car_Pricedf
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
car_Horsepowerdf=pd.DataFrame(car_Horsepower)
car_Horsepowerdf
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
Car_Pricedf.shape
# Out:
# (4, 2)

# %%
car_Horsepowerdf.shape
# Out:
# (4, 2)

# %%
Totaldf=pd.concat([Car_Pricedf,car_Horsepowerdf],ignore_index=True)
Totaldf
# Out:
#   Company     Price  horsepower
# 0  Toyota   23845.0         NaN
# 1   Honda   17995.0         NaN
# 2     BMV  135925.0         NaN
# 3    Audi   71400.0         NaN
# 4  Toyota       NaN       141.0
# 5   Honda       NaN        80.0
# 6     BMV       NaN       182.0
# 7    Audi       NaN       160.0

# %%
df_merge_col = pd.merge(Car_Pricedf,car_Horsepowerdf,on='Company')
df_merge_col
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
#The FULL OUTER JOIN combines the results of both the left and the right outer joins. The joined DataFrame will contain all records from both the DataFrames and fill in NaNs for missing matches on either side. You can perform a full outer join by specifying the how argument as outer in the merge() function:
df_outer = pd.merge(Car_Pricedf,car_Horsepowerdf, on="Company",how="outer")
df_outer
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
#The INNER JOIN produces only the set of records that match in both DataFrame A and DataFrame B. You have to pass inner in the how argument of merge() function to do inner join:
df_inner = pd.merge(Car_Pricedf,car_Horsepowerdf, on='Company', how='inner')
df_inner
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
#The RIGHT JOIN produces a complete set of records from DataFrame B (right DataFrame), with the matching records (where available) in DataFrame A (left DataFrame). If there is no match, the right side will contain null. You have to pass right in the how argument of merge() function to do right join:
df_right = pd.merge(Car_Pricedf,car_Horsepowerdf, on='Company', how='right')
df_right
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
#The Left Join.
#The LEFT JOIN produces a complete set of records from DataFrame A (left DataFrame), with the matching records (where available) in DataFrame B (right DataFrame). If there is no match, the left side will contain null. You have to pass left in the how argument of merge() function to do left join:
df_left = pd.merge(Car_Pricedf,car_Horsepowerdf, on='Company', how='left')
df_left
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
#28.Create two data frames using the dictionaries below, Concatenate those two dataframes and create a key for each data frame
#Hint syntax for concat : new_dataframe = pd.concat([dataframe1,dataframe2], keys=['key1', 'key2'])
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845,
171995, 135925 , 71400]}

GermanCarsdf=pd.DataFrame(GermanCars)
GermanCarsdf
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
#28.
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price':
[29995, 23600, 61500,58900]}
japaneseCarsdf=pd.DataFrame(japaneseCars)
japaneseCarsdf
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
#28.
frames=[GermanCarsdf,japaneseCarsdf]
TotalCarsdf=pd.concat(frames,keys=["key1","key2"])
TotalCarsdf
# Out:
#             Company   Price
# key1 0         Ford   23845
#      1     Mercedes  171995
#      2          BMV  135925
#      3         Audi   71400
# key2 0       Toyota   29995
#      1        Honda   23600
#      2       Nissan   61500
#      3  Mitsubishi    58900
